# %%
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#setting working dorectory
os.chdir('C:\\Users\\ss\\Documents\\Data Science assignment\\Python for Data science assignment')

# %%
# To read data
df= pd.read_excel('iris.xls')

# %%
#viewing forst five rows of data
df.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
df.tail()
# Out:
#       SL   SW   PL   PW  Classification
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %%
#to display the columns in data
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
#to check the column data type
df.dtypes
# Out:
# SL                float64
# SW                float64
# PL                float64
# PW                float64
# Classification     object
# dtype: object

# %%
# to check if there is any null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# to calculate mean for each columns
df.mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
# Distribution of data set
df['Classification'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Classification, dtype: int64

# %%
iri_versicolor=df.loc[df['Classification']=='Iris-versicolor'].values
iris_virginica=df.loc[df['Classification']== 'Iris-virginica'].values
iris_setosa=df.loc[df['Classification']=='Iris-setosa'].values

# %%
#visualization

sl1= df.loc[:,'SL'].values
pl1=df.loc[:,'PL'].values
sw1=df.loc[:,'SW'].values
pw1=df.loc[:,'PW'].values

# %%
#line graph
plt.plot(sl1, label= 'SL')
plt.plot(sw1, label='SW')

plt.legend()

# %%
plt.plot(pl1, label='PL')
plt.plot(pw1, label='PW')

plt.legend()

# %%
#box plot
sns.boxplot(x='Classification', y='SL', data=df)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='SL'>

# %%
sns.boxplot(x='Classification', y='SW', data=df)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='SW'>

# %%
sns.boxplot(x='Classification', y='PL', data=df)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='PL'>

# %%
sns.boxplot(x='Classification', y='PW', data=df)
# Out:
# <AxesSubplot:xlabel='Classification', ylabel='PW'>

# %%
#Histogram
plt.figure(figsize=(10,10))
plt.hist(df['SL'])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn')
sl_filter= df.loc[:,'Classification']=='Iris-virginica'
df.loc[sl_filter,'SL'].hist(bins=30,edgecolor='black')
plt.title("Iris-Virginica  with respect to SL")
# Out:
# Text(0.5, 1.0, 'Iris-Virginica  with respect to SL')

# %%
plt.style.use('ggplot')
sl_filter=df.loc[:,'Classification']=='Iris-versicolor'
df.loc[sl_filter, 'SL'].hist(bins=30,edgecolor='black')
plt.title('Iris-versicolor with respect to SL')
# Out:
# Text(0.5, 1.0, 'Iris-versicolor with respect to SL')

# %%
sl_filter=df.loc[:,'Classification']=='Iris-setosa'
df.loc[sl_filter,'SL'].hist(bins=30, edgecolor='black')
plt.title('Iris-setosa with respect to SL')
# Out:
# Text(0.5, 1.0, 'Iris-setosa with respect to SL')

# %%
#Count plot
sns.countplot(df['SL'])
# Out:
# C:\Users\ss\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SL', ylabel='count'>
